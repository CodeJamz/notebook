# %% [markdown]
# ## Version Control System / Source Code Manager
# ### 版本控制系统/源代码管理器
# A version control system (abbreviated as VCS) is a tool that manages different versions of source code. A source code manager (abbreviated as SCM) is another name for a version control system.
# - 版本控制系统（缩写为VCS）是管理源代码的不同版本的工具。源代码管理器（缩写为SCM）是版本控制系统的另一个名称。
#
# Git is an SCM (and therefore a VCS!). The URL for the Git website is https://git-scm.com/ (see how it has "SCM" <brdirectly in its domain!).
# - Git是一个SCM（因此是VCS！）。Git网站的URL是https://git-scm.com/ （请参见如何直接在其域中包含“ SCM”！）。
#
# ---
#
# ## Commit
# ### 提交
# Git thinks of its data like a set of snapshots of a mini filesystem. Every time you **commit** (save the state of your project in Git), it basically takes a picture of what all your files look like at that moment and stores a reference to that snapshot. You can think of it as a save point in a game - it saves your project's files and any information about them.
# - Git将其数据视为小型文件系统的快照集。每次您提交（在Git中保存项目的状态）时，它基本上都会拍下当时所有文件的样子，并存储对该快照的引用。您可以将其视为游戏中的保存点-它可以保存项目的文件以及有关文件的任何信息。
#
# Everything you do in Git is to help you make commits, so a commit is the fundamental unit in Git.
# - 您在Git中所做的一切都是为了帮助您进行提交，因此提交是Git中的基本单元。
#
# ---
#
# ## Repository / repo
# ### 仓库/仓库
# A **epository** is a directory which contains your project work, as well as a few files (hidden by default on Mac OS X) which are used to communicate with Git. Repositories can exist either locally on your computer or as a remote copy on another computer. A repository is made up of commits.
# - 资源库是一个目录，其中包含您的项目工作以及一些用于与Git通信的文件（在Mac OS X上默认为隐藏）。存储库可以在计算机本地存在，也可以作为另一台计算机上的远程副本存在。存储库由提交组成。
#
# ---
#
# ## Working Directory
# ### 工作目录
# The **Working Directory** is the files that you see in your computer's file system. When you open your project files up on a code editor, you're working with files in the Working Directory.
# - 工作目录是您在计算机文件系统中看到的文件。当您在代码编辑器中打开项目文件时，您正在使用工作目录中的文件。
#
# This is in contrast to the files that have been saved (in commits!) in the repository.
# - 这与已保存的文件（在提交中）在仓库里形成对比。
#
# When working with Git, the Working Directory is also different from the command line's concept of the current working directory which is the directory that your shell is "looking at" right now.
# - 使用Git时，工作目录也不同于命令行中当前工作目录的概念，当前工作目录是您的Shell当前正在“查看”的目录。
#
# ---
#
# ## Checkout
# ### 签出
# A **checkout** is when content in the repository has been copied to the Working Directory.
# - 签出是将存储库中的内容复制到工作目录中的时间。
#
# ---
#
# ## Staging Area / Staging Index / Index
# ### 暂存区/暂存索引/索引
# A file in the Git directory that stores information about what will go into your next commit. You can think of the staging area as a prep table where Git will take the next commit. Files on the Staging Index are poised to be added to the repository.
# - Git目录中的一个文件，用于存储有关下一次提交的内容的信息。您可以将登台区域视为一个准备表，Git将在该准备表中进行下一次提交。准备将暂存索引上的文件添加到存储库中。
#
# ---
#
# ## SHA
# ### SHA
# A **SHA** is basically an ID number for each commit. Here's what a commit's SHA might look like: e2adf8ae3e2e4ed40add75cc44cf9d0a869afeb6.
# - SHA基本上是每次提交的ID号。提交的SHA可能看起来像这样：e2adf8ae3e2e4ed40add75cc44cf9d0a869afeb6。
#
# It is a 40-character string composed of characters (0–9 and a–f) and calculated based on the contents of a file or directory structure in Git. "SHA" is shorthand for "Secure Hash Algorithm".
# - 它是一个由40个字符组成的字符串，由字符（0-9和af）组成，并根据Git中文件或目录结构的内容进行计算。“ SHA”是“安全哈希算法”的简写。
#
# ---
#
# ## Branch
# ### 分支
# A **branch** is when a new line of development is created that diverges from the main line of development. This alternative line of development can continue without altering the main line.
# - 分支是指新的开发线与主要开发线不同时。这种替代性的开发路线可以继续进行，而无需更改主线。
#
# Going back to the example of save point in a game, you can think of a branch as where you make a save point in your game and then decide to try out a risky move in the game. If the risky move doesn't pan out, then you can just go back to the save point. The key thing that makes branches incredibly powerful is that you can make save points on one branch, and then switch to a different branch and make save points there, too.
# - 回到游戏中保存点的示例，您可以将分支视为在游戏中保存点的位置，然后决定尝试游戏中的冒险动作。如果冒险的举动没有成功，那么您可以回到保存点。 使分支功能异常强大的关键在于，您可以在一个分支上创建保存点，然后切换到另一个分支，并在那里创建保存点。
#
# With this terminology in mind, let's take a high-level look at how we'll be using Git by looking at the typical workflow when working with version control.
